# %%
#Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list of cities .
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port hardy
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | nantucket
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | avera
# Processing Record 6 of Set 1 | pingliang
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | vila franca do campo
# Processing Record 10 of Set 1 | ponta do sol
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | cayenne
# Processing Record 13 of Set 1 | carnarvon
# Processing Record 14 of Set 1 | barinas
# Processing Record 15 of Set 1 | port macquarie
# Processing Record 16 of Set 1 | inuvik
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | ust-kut
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | marystown
# Processing Record 23 of Set 1 | faanui
# Processing Record 24 of Set 1 | milledgeville
# Processing Record 25 of Set 1 | ilulissat
# Processing Record 26 of Set 1 | leh
# Processing Record 27 of Set 1 | geraldton
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | biak
# Processing Record 30 of Set 1 | elko
# Processing Record 31 of Set 1 | kandrian
# Processing Record 32 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | clyde river
# Processing Record 35 of Set 1 | meadow lake
# Processing Record 36 of Set 1 | vlist
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | bambous virieux
# Processing Record 39 of Set 1 | cherskiy
# Processing Record 40 of Set 1 | nanakuli
# Processing Record 41 of Set 1 | floriano
# Processing Record 42 of Set 1 | san jeronimo
# Processing Record 43 of Set 1 | borogontsy
# Processing Record 44 of Set 1 | saldanha
# Processing Record 45 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | marawi
# Processing Record 49 of Set 1 | manaure
# Processing Record 50 of Set 1 | los llanos de aridane
# Processing Record 1 of Set 2 | presidencia roque saenz pena
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | fortuna
# Processing Record 6 of Set 2 | omboue
# Processing Record 7 of Set 2 | upernavik
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | don matias
# Processing Record 10 of Set 2 | green river
# Processing Record 11 of Set 2 | udachnyy
# Processing Record 12 of Set 2 | sembe
# Processing Record 13 of Set 2 | mahebourg
# Processing Record 14 of Set 2 | winsum
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | esperance
# Processing Record 17 of Set 2 | vestmannaeyjar
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | half moon bay
# Processing Record 20 of Set 2 | sunyani
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | katsuura
# Processing Record 23 of Set 2 | okhotsk
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | acarau
# Processing Record 26 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 | husavik
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | bembereke
# Processing Record 30 of Set 2 | alofi
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | ratnagiri
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | egvekinot
# Processing Record 35 of Set 2 | ostrovnoy
# Processing Record 36 of Set 2 | ancud
# Processing Record 37 of Set 2 | braco do norte
# Processing Record 38 of Set 2 | puerto ayora
# Processing Record 39 of Set 2 | brae
# Processing Record 40 of Set 2 | katobu
# Processing Record 41 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 2 | broome
# Processing Record 43 of Set 2 | deputatskiy
# Processing Record 44 of Set 2 | sur
# Processing Record 45 of Set 2 | beringovskiy
# Processing Record 46 of Set 2 | sisimiut
# Processing Record 47 of Set 2 | umm lajj
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | henties bay
# Processing Record 50 of Set 2 | pontianak
# Processing Record 1 of Set 3 | tuktoyaktuk
# Processing Record 2 of Set 3 | hilo
# Processing Record 3 of Set 3 | kruisfontein
# Processing Record 4 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 3 | caravelas
# Processing Record 6 of Set 3 | salinopolis
# Processing Record 7 of Set 3 | alamogordo
# Processing Record 8 of Set 3 | poum
# Processing Record 9 of Set 3 | estelle
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | saint-augustin
# Processing Record 12 of Set 3 | togur
# Processing Record 13 of Set 3 | andenes
# Processing Record 14 of Set 3 | yizheng
# Processing Record 15 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | zeya
# Processing Record 18 of Set 3 | gander
# Processing Record 19 of Set 3 | uklana mandi
# Processing Record 20 of Set 3 | kingsland
# Processing Record 21 of Set 3 | altay
# Processing Record 22 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 3 | yarada
# Processing Record 25 of Set 3 | albany
# Processing Record 26 of Set 3 | taseyevo
# Processing Record 27 of Set 3 | bluff
# Processing Record 28 of Set 3 | longyearbyen
# Processing Record 29 of Set 3 | nioro
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | nome
# Processing Record 32 of Set 3 | burica
# City not found. Skipping...
# Processing Record 33 of Set 3 | santa rosa
# Processing Record 34 of Set 3 | beloha
# Processing Record 35 of Set 3 | erechim
# Processing Record 36 of Set 3 | barrow
# Processing Record 37 of Set 3 | mangrol
# Processing Record 38 of Set 3 | mar del plata
# Processing Record 39 of Set 3 | araguatins
# City not found. Skipping...
# Processing Record 40 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 3 | torbay
# Processing Record 42 of Set 3 | strezhevoy
# Processing Record 43 of Set 3 | marsh harbour
# Processing Record 44 of Set 3 | pemangkat
# Processing Record 45 of Set 3 | bom jesus
# Processing Record 46 of Set 3 | siocon
# Processing Record 47 of Set 3 | bonthe
# Processing Record 48 of Set 3 | sao jose da coroa grande
# Processing Record 49 of Set 3 | novyy urgal
# Processing Record 50 of Set 3 | caconda
# Processing Record 1 of Set 4 | norman wells
# Processing Record 2 of Set 4 | lorengau
# Processing Record 3 of Set 4 | atambua
# Processing Record 4 of Set 4 | manaus
# Processing Record 5 of Set 4 | bethel
# Processing Record 6 of Set 4 | nalut
# Processing Record 7 of Set 4 | hauterive
# Processing Record 8 of Set 4 | khasan
# Processing Record 9 of Set 4 | kodiak
# Processing Record 10 of Set 4 | cabo san lucas
# Processing Record 11 of Set 4 | gurgan
# City not found. Skipping...
# Processing Record 12 of Set 4 | gondar
# Processing Record 13 of Set 4 | hamilton
# Processing Record 14 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 4 | ketchikan
# Processing Record 16 of Set 4 | lasa
# Processing Record 17 of Set 4 | camacha
# Processing Record 18 of Set 4 | batala
# Processing Record 19 of Set 4 | listvyagi
# Processing Record 20 of Set 4 | hobyo
# Processing Record 21 of Set 4 | christchurch
# Processing Record 22 of Set 4 | adrar
# Processing Record 23 of Set 4 | mount gambier
# Processing Record 24 of Set 4 | port augusta
# Processing Record 25 of Set 4 | east london
# Processing Record 26 of Set 4 | seoul
# Processing Record 27 of Set 4 | lebu
# Processing Record 28 of Set 4 | nouadhibou
# Processing Record 29 of Set 4 | hirara
# Processing Record 30 of Set 4 | makakilo city
# Processing Record 31 of Set 4 | lynn haven
# Processing Record 32 of Set 4 | oriximina
# Processing Record 33 of Set 4 | hammerfest
# Processing Record 34 of Set 4 | provideniya
# Processing Record 35 of Set 4 | arraial do cabo
# Processing Record 36 of Set 4 | gat
# Processing Record 37 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 4 | krasnoselkup
# Processing Record 39 of Set 4 | padang
# Processing Record 40 of Set 4 | nyimba
# Processing Record 41 of Set 4 | lata
# Processing Record 42 of Set 4 | noshiro
# Processing Record 43 of Set 4 | constitucion
# Processing Record 44 of Set 4 | eyl
# Processing Record 45 of Set 4 | grindavik
# Processing Record 46 of Set 4 | akdagmadeni
# Processing Record 47 of Set 4 | banda aceh
# Processing Record 48 of Set 4 | the valley
# Processing Record 49 of Set 4 | miles city
# Processing Record 50 of Set 4 | peniche
# Processing Record 1 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 2 of Set 5 | ystad
# Processing Record 3 of Set 5 | laguna
# Processing Record 4 of Set 5 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 5 of Set 5 | pyapon
# Processing Record 6 of Set 5 | aykhal
# Processing Record 7 of Set 5 | vardo
# Processing Record 8 of Set 5 | sioux lookout
# Processing Record 9 of Set 5 | madang
# Processing Record 10 of Set 5 | marrakesh
# Processing Record 11 of Set 5 | saskylakh
# Processing Record 12 of Set 5 | sitka
# Processing Record 13 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 5 | rawson
# Processing Record 15 of Set 5 | medea
# Processing Record 16 of Set 5 | dongsheng
# Processing Record 17 of Set 5 | portland
# Processing Record 18 of Set 5 | gostinu
# Processing Record 19 of Set 5 | grenville
# Processing Record 20 of Set 5 | srostki
# Processing Record 21 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 22 of Set 5 | obra
# Processing Record 23 of Set 5 | talnakh
# Processing Record 24 of Set 5 | sitionuevo
# Processing Record 25 of Set 5 | port pirie
# Processing Record 26 of Set 5 | sheregesh
# Processing Record 27 of Set 5 | tecoanapa
# Processing Record 28 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 5 | verkhoyansk
# Processing Record 30 of Set 5 | tamworth
# Processing Record 31 of Set 5 | mayo
# Processing Record 32 of Set 5 | bengkulu
# Processing Record 33 of Set 5 | comodoro rivadavia
# Processing Record 34 of Set 5 | kapaa
# Processing Record 35 of Set 5 | port blair
# Processing Record 36 of Set 5 | salalah
# Processing Record 37 of Set 5 | chuy
# Processing Record 38 of Set 5 | lake charles
# Processing Record 39 of Set 5 | atar
# Processing Record 40 of Set 5 | mirabad
# Processing Record 41 of Set 5 | coahuayana
# Processing Record 42 of Set 5 | hun
# Processing Record 43 of Set 5 | taltal
# Processing Record 44 of Set 5 | mount isa
# Processing Record 45 of Set 5 | klaksvik
# Processing Record 46 of Set 5 | fuling
# Processing Record 47 of Set 5 | lappeenranta
# Processing Record 48 of Set 5 | sobolevo
# Processing Record 49 of Set 5 | nanortalik
# Processing Record 50 of Set 5 | kysyl-syr
# Processing Record 1 of Set 6 | buraydah
# Processing Record 2 of Set 6 | vestmanna
# Processing Record 3 of Set 6 | saint george
# Processing Record 4 of Set 6 | dubbo
# Processing Record 5 of Set 6 | ust-nera
# Processing Record 6 of Set 6 | emba
# Processing Record 7 of Set 6 | nikolskoye
# Processing Record 8 of Set 6 | saintes
# Processing Record 9 of Set 6 | ahipara
# Processing Record 10 of Set 6 | matara
# Processing Record 11 of Set 6 | ihosy
# Processing Record 12 of Set 6 | santa cruz de tenerife
# Processing Record 13 of Set 6 | srednekolymsk
# Processing Record 14 of Set 6 | chichicapam
# City not found. Skipping...
# Processing Record 15 of Set 6 | moose jaw
# Processing Record 16 of Set 6 | alyangula
# Processing Record 17 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 6 | muli
# Processing Record 19 of Set 6 | vadso
# Processing Record 20 of Set 6 | bukachacha
# Processing Record 21 of Set 6 | fairbanks
# Processing Record 22 of Set 6 | zaykovo
# Processing Record 23 of Set 6 | zhanaozen
# Processing Record 24 of Set 6 | dunedin
# Processing Record 25 of Set 6 | smithers
# Processing Record 26 of Set 6 | ajdabiya
# Processing Record 27 of Set 6 | fort saint james
# Processing Record 28 of Set 6 | sibolga
# Processing Record 29 of Set 6 | kathu
# Processing Record 30 of Set 6 | leningradskiy
# Processing Record 31 of Set 6 | los algarrobos
# Processing Record 32 of Set 6 | havoysund
# Processing Record 33 of Set 6 | katherine
# Processing Record 34 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 6 | trinidad
# Processing Record 36 of Set 6 | sorland
# Processing Record 37 of Set 6 | saint-philippe
# Processing Record 38 of Set 6 | shahr-e kord
# Processing Record 39 of Set 6 | rio gallegos
# Processing Record 40 of Set 6 | chokurdakh
# Processing Record 41 of Set 6 | hobart
# Processing Record 42 of Set 6 | matadi
# Processing Record 43 of Set 6 | butaritari
# Processing Record 44 of Set 6 | kvarkeno
# Processing Record 45 of Set 6 | monrovia
# Processing Record 46 of Set 6 | lanzhou
# Processing Record 47 of Set 6 | devonport
# Processing Record 48 of Set 6 | dawei
# Processing Record 49 of Set 6 | kungurtug
# Processing Record 50 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 7 | port lincoln
# Processing Record 2 of Set 7 | tiksi
# Processing Record 3 of Set 7 | airai
# Processing Record 4 of Set 7 | kamyshin
# Processing Record 5 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 6 of Set 7 | kuhdasht
# Processing Record 7 of Set 7 | griffith
# Processing Record 8 of Set 7 | haines junction
# Processing Record 9 of Set 7 | aden
# Processing Record 10 of Set 7 | axim
# Processing Record 11 of Set 7 | dharmadam
# Processing Record 12 of Set 7 | quebo
# Processing Record 13 of Set 7 | trincomalee
# Processing Record 14 of Set 7 | palmer
# Processing Record 15 of Set 7 | westport
# Processing Record 16 of Set 7 | rosarito
# Processing Record 17 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 7 | te anau
# Processing Record 19 of Set 7 | codrington
# Processing Record 20 of Set 7 | manica
# Processing Record 21 of Set 7 | novopokrovka
# Processing Record 22 of Set 7 | tocopilla
# Processing Record 23 of Set 7 | havelock
# Processing Record 24 of Set 7 | coihaique
# Processing Record 25 of Set 7 | berdigestyakh
# Processing Record 26 of Set 7 | nur
# Processing Record 27 of Set 7 | goderich
# Processing Record 28 of Set 7 | krokeai
# Processing Record 29 of Set 7 | great falls
# Processing Record 30 of Set 7 | bandarbeyla
# Processing Record 31 of Set 7 | kahului
# Processing Record 32 of Set 7 | pangody
# Processing Record 33 of Set 7 | guerrero negro
# Processing Record 34 of Set 7 | cancun
# Processing Record 35 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 7 | tanout
# Processing Record 37 of Set 7 | high level
# Processing Record 38 of Set 7 | chapais
# Processing Record 39 of Set 7 | awjilah
# Processing Record 40 of Set 7 | xixiang
# Processing Record 41 of Set 7 | ishigaki
# Processing Record 42 of Set 7 | leshukonskoye
# Processing Record 43 of Set 7 | waipawa
# Processing Record 44 of Set 7 | kavaratti
# Processing Record 45 of Set 7 | itaituba
# Processing Record 46 of Set 7 | nyahururu
# Processing Record 47 of Set 7 | santa maria
# Processing Record 48 of Set 7 | vikindu
# Processing Record 49 of Set 7 | chulucanas
# Processing Record 50 of Set 7 | rochegda
# Processing Record 1 of Set 8 | bilma
# Processing Record 2 of Set 8 | aitape
# Processing Record 3 of Set 8 | coquimbo
# Processing Record 4 of Set 8 | carnaiba
# Processing Record 5 of Set 8 | kudahuvadhoo
# Processing Record 6 of Set 8 | kavieng
# Processing Record 7 of Set 8 | dauriya
# Processing Record 8 of Set 8 | puerto suarez
# Processing Record 9 of Set 8 | la rioja
# Processing Record 10 of Set 8 | khomeyn
# Processing Record 11 of Set 8 | omuta
# Processing Record 12 of Set 8 | jacareacanga
# Processing Record 13 of Set 8 | richards bay
# Processing Record 14 of Set 8 | smoky lake
# Processing Record 15 of Set 8 | hofn
# Processing Record 16 of Set 8 | northam
# Processing Record 17 of Set 8 | dikson
# Processing Record 18 of Set 8 | vanavara
# Processing Record 19 of Set 8 | suba
# Processing Record 20 of Set 8 | kirakira
# Processing Record 21 of Set 8 | seddon
# Processing Record 22 of Set 8 | itarema
# Processing Record 23 of Set 8 | tanggu
# Processing Record 24 of Set 8 | sarangani
# Processing Record 25 of Set 8 | aswan
# Processing Record 26 of Set 8 | hasaki
# Processing Record 27 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 8 | buala
# Processing Record 29 of Set 8 | luderitz
# Processing Record 30 of Set 8 | kudinovo
# Processing Record 31 of Set 8 | nong han
# Processing Record 32 of Set 8 | hearst
# Processing Record 33 of Set 8 | nizhniy baskunchak
# Processing Record 34 of Set 8 | taft
# Processing Record 35 of Set 8 | suez
# Processing Record 36 of Set 8 | plettenberg bay
# Processing Record 37 of Set 8 | port elizabeth
# Processing Record 38 of Set 8 | changping
# Processing Record 39 of Set 8 | zhuhai
# Processing Record 40 of Set 8 | klin
# Processing Record 41 of Set 8 | mengyin
# Processing Record 42 of Set 8 | dawson creek
# Processing Record 43 of Set 8 | freeport
# Processing Record 44 of Set 8 | fare
# Processing Record 45 of Set 8 | rovinari
# Processing Record 46 of Set 8 | souillac
# Processing Record 47 of Set 8 | tete
# Processing Record 48 of Set 8 | xuanhua
# Processing Record 49 of Set 8 | port-de-bouc
# Processing Record 50 of Set 8 | koungou
# Processing Record 1 of Set 9 | biryusinsk
# Processing Record 2 of Set 9 | lompoc
# Processing Record 3 of Set 9 | albanel
# Processing Record 4 of Set 9 | baruun-urt
# Processing Record 5 of Set 9 | cidreira
# Processing Record 6 of Set 9 | ati
# Processing Record 7 of Set 9 | eregli
# Processing Record 8 of Set 9 | ambilobe
# Processing Record 9 of Set 9 | vila velha
# Processing Record 10 of Set 9 | rumford
# Processing Record 11 of Set 9 | batemans bay
# Processing Record 12 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 9 | lavrentiya
# Processing Record 14 of Set 9 | broken hill
# Processing Record 15 of Set 9 | jasper
# Processing Record 16 of Set 9 | narsaq
# Processing Record 17 of Set 9 | kijang
# Processing Record 18 of Set 9 | acoyapa
# Processing Record 19 of Set 9 | nosy varika
# Processing Record 20 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 21 of Set 9 | kimbe
# Processing Record 22 of Set 9 | whitehaven
# Processing Record 23 of Set 9 | along
# Processing Record 24 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 25 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 9 | tasiilaq
# Processing Record 27 of Set 9 | arica
# Processing Record 28 of Set 9 | isangel
# Processing Record 29 of Set 9 | yendi
# Processing Record 30 of Set 9 | rio verde de mato grosso
# Processing Record 31 of Set 9 | buin
# Processing Record 32 of Set 9 | qasigiannguit
# Processing Record 33 of Set 9 | lashio
# Processing Record 34 of Set 9 | erenhot
# Processing Record 35 of Set 9 | alice springs
# Processing Record 36 of Set 9 | swellendam
# Processing Record 37 of Set 9 | benghazi
# Processing Record 38 of Set 9 | mersing
# Processing Record 39 of Set 9 | qujing
# Processing Record 40 of Set 9 | yulara
# Processing Record 41 of Set 9 | asosa
# Processing Record 42 of Set 9 | mandurah
# Processing Record 43 of Set 9 | chipinge
# Processing Record 44 of Set 9 | luena
# Processing Record 45 of Set 9 | tianpeng
# Processing Record 46 of Set 9 | berlevag
# Processing Record 47 of Set 9 | tuatapere
# Processing Record 48 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 49 of Set 9 | matias barbosa
# Processing Record 50 of Set 9 | ituporanga
# Processing Record 1 of Set 10 | granada
# Processing Record 2 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 10 | margate
# Processing Record 4 of Set 10 | joshimath
# Processing Record 5 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 10 | samana
# Processing Record 7 of Set 10 | antalaha
# Processing Record 8 of Set 10 | oranjestad
# Processing Record 9 of Set 10 | clinton
# Processing Record 10 of Set 10 | nansio
# Processing Record 11 of Set 10 | blitar
# Processing Record 12 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 10 | salur
# Processing Record 14 of Set 10 | noumea
# Processing Record 15 of Set 10 | samarai
# Processing Record 16 of Set 10 | manzil jamil
# City not found. Skipping...
# Processing Record 17 of Set 10 | touros
# Processing Record 18 of Set 10 | port-gentil
# Processing Record 19 of Set 10 | taoudenni
# Processing Record 20 of Set 10 | port washington
# Processing Record 21 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 22 of Set 10 | nyuksenitsa
# Processing Record 23 of Set 10 | san quintin
# Processing Record 24 of Set 10 | callaway
# Processing Record 25 of Set 10 | shakawe
# Processing Record 26 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 10 | port-cartier
# Processing Record 28 of Set 10 | kieta
# Processing Record 29 of Set 10 | saint thomas
# Processing Record 30 of Set 10 | namatanai
# Processing Record 31 of Set 10 | akyab
# Processing Record 32 of Set 10 | vanimo
# Processing Record 33 of Set 10 | khorixas
# Processing Record 34 of Set 10 | yerbogachen
# Processing Record 35 of Set 10 | norden
# Processing Record 36 of Set 10 | daloa
# Processing Record 37 of Set 10 | san vicente
# Processing Record 38 of Set 10 | severo-yeniseyskiy
# Processing Record 39 of Set 10 | moose factory
# Processing Record 40 of Set 10 | tahta
# Processing Record 41 of Set 10 | carahue
# Processing Record 42 of Set 10 | preobrazheniye
# Processing Record 43 of Set 10 | jumla
# Processing Record 44 of Set 10 | solano
# Processing Record 45 of Set 10 | maragogi
# Processing Record 46 of Set 10 | wagga wagga
# Processing Record 47 of Set 10 | tomakomai
# Processing Record 48 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 10 | la tuque
# Processing Record 50 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 1 of Set 11 | iqaluit
# Processing Record 2 of Set 11 | batagay-alyta
# Processing Record 3 of Set 11 | lagoa
# Processing Record 4 of Set 11 | straumen
# Processing Record 5 of Set 11 | trairi
# Processing Record 6 of Set 11 | paripiranga
# Processing Record 7 of Set 11 | xai-xai
# Processing Record 8 of Set 11 | svatove
# Processing Record 9 of Set 11 | rudnaya pristan
# Processing Record 10 of Set 11 | sabibah
# City not found. Skipping...
# Processing Record 11 of Set 11 | belen
# Processing Record 12 of Set 11 | huarmey
# Processing Record 13 of Set 11 | lagdo
# Processing Record 14 of Set 11 | ugoofaaru
# Processing Record 15 of Set 11 | kaeo
# Processing Record 16 of Set 11 | namibe
# Processing Record 17 of Set 11 | dombarovskiy
# Processing Record 18 of Set 11 | aparecida
# Processing Record 19 of Set 11 | corsicana
# Processing Record 20 of Set 11 | vilyuysk
# Processing Record 21 of Set 11 | bubaque
# Processing Record 22 of Set 11 | santa teresa
# Processing Record 23 of Set 11 | sagaing
# Processing Record 24 of Set 11 | sindor
# Processing Record 25 of Set 11 | saint-pierre
# Processing Record 26 of Set 11 | praia da vitoria
# Processing Record 27 of Set 11 | nouakchott
# Processing Record 28 of Set 11 | bilibino
# Processing Record 29 of Set 11 | labuhan
# Processing Record 30 of Set 11 | krasnyy chikoy
# Processing Record 31 of Set 11 | aiken
# Processing Record 32 of Set 11 | tiarei
# Processing Record 33 of Set 11 | meulaboh
# Processing Record 34 of Set 11 | hervey bay
# Processing Record 35 of Set 11 | stromness
# Processing Record 36 of Set 11 | yeletskiy
# City not found. Skipping...
# Processing Record 37 of Set 11 | dukat
# Processing Record 38 of Set 11 | aklavik
# Processing Record 39 of Set 11 | burlington
# Processing Record 40 of Set 11 | saint-joseph
# Processing Record 41 of Set 11 | polunochnoye
# Processing Record 42 of Set 11 | bakreswar
# Processing Record 43 of Set 11 | nelson bay
# Processing Record 44 of Set 11 | vostok
# Processing Record 45 of Set 11 | hay river
# Processing Record 46 of Set 11 | gari
# Processing Record 47 of Set 11 | tezu
# Processing Record 48 of Set 11 | dubenskiy
# City not found. Skipping...
# Processing Record 49 of Set 11 | morondava
# Processing Record 50 of Set 11 | bambanglipuro
# Processing Record 1 of Set 12 | antofagasta
# Processing Record 2 of Set 12 | dandong
# Processing Record 3 of Set 12 | sola
# Processing Record 4 of Set 12 | mansa
# Processing Record 5 of Set 12 | flin flon
# Processing Record 6 of Set 12 | nuuk
# Processing Record 7 of Set 12 | labuan
# Processing Record 8 of Set 12 | launceston
# Processing Record 9 of Set 12 | verkhnevilyuysk
# Processing Record 10 of Set 12 | ahuimanu
# Processing Record 11 of Set 12 | ascona
# Processing Record 12 of Set 12 | muros
# Processing Record 13 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 14 of Set 12 | chernyshevskiy
# Processing Record 15 of Set 12 | iranshahr
# Processing Record 16 of Set 12 | wajima
# Processing Record 17 of Set 12 | gumushane
# City not found. Skipping...
# Processing Record 18 of Set 12 | kazachinskoye
# Processing Record 19 of Set 12 | acajutla
# Processing Record 20 of Set 12 | kokstad
# Processing Record 21 of Set 12 | tura
# Processing Record 22 of Set 12 | wamba
# Processing Record 23 of Set 12 | arman
# Processing Record 24 of Set 12 | ukiah
# Processing Record 25 of Set 12 | saint anthony
# Processing Record 26 of Set 12 | saint-denis
# Processing Record 27 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 28 of Set 12 | xichang
# Processing Record 29 of Set 12 | vao
# Processing Record 30 of Set 12 | acapulco
# Processing Record 31 of Set 12 | erzin
# Processing Record 32 of Set 12 | north battleford
# Processing Record 33 of Set 12 | povenets
# Processing Record 34 of Set 12 | beaufort
# Processing Record 35 of Set 12 | praia
# Processing Record 36 of Set 12 | anadyr
# Processing Record 37 of Set 12 | paamiut
# Processing Record 38 of Set 12 | yeppoon
# Processing Record 39 of Set 12 | kalmunai
# Processing Record 40 of Set 12 | tazovskiy
# Processing Record 41 of Set 12 | olafsvik
# Processing Record 42 of Set 12 | auki
# Processing Record 43 of Set 12 | mayumba
# Processing Record 44 of Set 12 | luau
# Processing Record 45 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 46 of Set 12 | beira
# Processing Record 47 of Set 12 | mezen
# Processing Record 48 of Set 12 | arauca
# Processing Record 49 of Set 12 | kamogawa
# Processing Record 50 of Set 12 | naryan-mar
# Processing Record 1 of Set 13 | bina-etawa
# City not found. Skipping...
# Processing Record 2 of Set 13 | mecca
# Processing Record 3 of Set 13 | soyo
# Processing Record 4 of Set 13 | la libertad
# Processing Record 5 of Set 13 | mawlaik
# Processing Record 6 of Set 13 | roma
# Processing Record 7 of Set 13 | cockburn town
# Processing Record 8 of Set 13 | huilong
# Processing Record 9 of Set 13 | sokoni
# Processing Record 10 of Set 13 | champaign
# Processing Record 11 of Set 13 | ca mau
# Processing Record 12 of Set 13 | shu
# Processing Record 13 of Set 13 | comarapa
# Processing Record 14 of Set 13 | palauig
# Processing Record 15 of Set 13 | mao
# Processing Record 16 of Set 13 | khandyga
# Processing Record 17 of Set 13 | ayan
# Processing Record 18 of Set 13 | agva
# City not found. Skipping...
# Processing Record 19 of Set 13 | dauphin
# Processing Record 20 of Set 13 | kenai
# Processing Record 21 of Set 13 | strelka
# Processing Record 22 of Set 13 | baghdad
# Processing Record 23 of Set 13 | staryy biser
# City not found. Skipping...
# Processing Record 24 of Set 13 | abu samrah
# Processing Record 25 of Set 13 | spearfish
# Processing Record 26 of Set 13 | datong
# Processing Record 27 of Set 13 | kargasok
# Processing Record 28 of Set 13 | waingapu
# Processing Record 29 of Set 13 | zhigansk
# Processing Record 30 of Set 13 | mitsamiouli
# Processing Record 31 of Set 13 | pangnirtung
# Processing Record 32 of Set 13 | puerto del rosario
# Processing Record 33 of Set 13 | barreirinha
# Processing Record 34 of Set 13 | almaznyy
# Processing Record 35 of Set 13 | quatre cocos
# Processing Record 36 of Set 13 | ascension
# Processing Record 37 of Set 13 | kapoeta
# Processing Record 38 of Set 13 | lac du bonnet
# Processing Record 39 of Set 13 | chimbote
# Processing Record 40 of Set 13 | formosa do rio preto
# Processing Record 41 of Set 13 | olinda
# Processing Record 42 of Set 13 | abu dhabi
# Processing Record 43 of Set 13 | naze
# Processing Record 44 of Set 13 | santo antonio do ica
# Processing Record 45 of Set 13 | hailin
# Processing Record 46 of Set 13 | tres arroyos
# Processing Record 47 of Set 13 | indiana
# Processing Record 48 of Set 13 | lom sak
# Processing Record 49 of Set 13 | komsomolskiy
# Processing Record 50 of Set 13 | celestun
# Processing Record 1 of Set 14 | totness
# Processing Record 2 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 14 | aksarka
# Processing Record 4 of Set 14 | nanyang
# Processing Record 5 of Set 14 | norfolk
# Processing Record 6 of Set 14 | seka
# Processing Record 7 of Set 14 | skiros
# City not found. Skipping...
# Processing Record 8 of Set 14 | ormara
# Processing Record 9 of Set 14 | san carlos de bariloche
# Processing Record 10 of Set 14 | ghanzi
# Processing Record 11 of Set 14 | koroni
# Processing Record 12 of Set 14 | lubumbashi
# Processing Record 13 of Set 14 | yurgamysh
# Processing Record 14 of Set 14 | shwebo
# Processing Record 15 of Set 14 | leme
# Processing Record 16 of Set 14 | sao joao da barra
# Processing Record 17 of Set 14 | college
# Processing Record 18 of Set 14 | vendas novas
# Processing Record 19 of Set 14 | cabedelo
# Processing Record 20 of Set 14 | koulamoutou
# Processing Record 21 of Set 14 | vagay
# Processing Record 22 of Set 14 | machico
# Processing Record 23 of Set 14 | changli
# Processing Record 24 of Set 14 | rocha
# Processing Record 25 of Set 14 | teluknaga
# Processing Record 26 of Set 14 | sorong
# Processing Record 27 of Set 14 | benjamin aceval
# Processing Record 28 of Set 14 | banff
# Processing Record 29 of Set 14 | sawtell
# Processing Record 30 of Set 14 | shimanovsk
# Processing Record 31 of Set 14 | forbes
# Processing Record 32 of Set 14 | ivolginsk
# Processing Record 33 of Set 14 | west wendover
# Processing Record 34 of Set 14 | neunkirchen
# Processing Record 35 of Set 14 | dakar
# Processing Record 36 of Set 14 | guia de isora
# Processing Record 37 of Set 14 | baneh
# Processing Record 38 of Set 14 | haapu
# City not found. Skipping...
# Processing Record 39 of Set 14 | langsa
# Processing Record 40 of Set 14 | gladstone
# Processing Record 41 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 42 of Set 14 | imbituba
# Processing Record 43 of Set 14 | corrientes
# Processing Record 44 of Set 14 | rosetta
# Processing Record 45 of Set 14 | elliot
# Processing Record 46 of Set 14 | milkovo
# Processing Record 47 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 48 of Set 14 | vung tau
# Processing Record 49 of Set 14 | boa vista
# Processing Record 50 of Set 14 | gazanjyk
# Processing Record 1 of Set 15 | rock sound
# Processing Record 2 of Set 15 | la paz
# Processing Record 3 of Set 15 | bingen
# Processing Record 4 of Set 15 | sao filipe
# Processing Record 5 of Set 15 | ucluelet
# Processing Record 6 of Set 15 | revelstoke
# Processing Record 7 of Set 15 | kismayo
# Processing Record 8 of Set 15 | puerto escondido
# Processing Record 9 of Set 15 | karratha
# Processing Record 10 of Set 15 | east moline
# Processing Record 11 of Set 15 | narsimhapur
# Processing Record 12 of Set 15 | coatzacoalcos
# Processing Record 13 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 14 of Set 15 | san patricio
# Processing Record 15 of Set 15 | esmeraldas
# Processing Record 16 of Set 15 | san rafael
# Processing Record 17 of Set 15 | limoges
# Processing Record 18 of Set 15 | sawakin
# Processing Record 19 of Set 15 | catamarca
# Processing Record 20 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 15 | tefe
# Processing Record 22 of Set 15 | kayerkan
# Processing Record 23 of Set 15 | netrakona
# Processing Record 24 of Set 15 | evensk
# Processing Record 25 of Set 15 | micheweni
# Processing Record 26 of Set 15 | asau
# Processing Record 27 of Set 15 | brawley
# Processing Record 28 of Set 15 | virginia beach
# Processing Record 29 of Set 15 | vangaindrano
# Processing Record 30 of Set 15 | jalu
# Processing Record 31 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 15 | fort-de-france
# Processing Record 33 of Set 15 | korcula
# Processing Record 34 of Set 15 | salumbar
# Processing Record 35 of Set 15 | korop
# Processing Record 36 of Set 15 | batalha
# Processing Record 37 of Set 15 | karasuk
# Processing Record 38 of Set 15 | msanga
# Processing Record 39 of Set 15 | kultuk
# Processing Record 40 of Set 15 | cabra
# Processing Record 41 of Set 15 | cabrobo
# Processing Record 42 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 43 of Set 15 | eisenerz
# Processing Record 44 of Set 15 | dingle
# Processing Record 45 of Set 15 | stara vyzhivka
# Processing Record 46 of Set 15 | bad ems
# Processing Record 47 of Set 15 | katima mulilo
# Processing Record 48 of Set 15 | parian dakula
# Processing Record 49 of Set 15 | roald
# Processing Record 50 of Set 15 | singapore
# Processing Record 1 of Set 16 | hohhot
# Processing Record 2 of Set 16 | kaseda
# Processing Record 3 of Set 16 | tubuala
# Processing Record 4 of Set 16 | ariquemes
# Processing Record 5 of Set 16 | chamonix-mont-blanc
# Processing Record 6 of Set 16 | safranbolu
# Processing Record 7 of Set 16 | calamar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Port Hardy  50.70 -127.42     42.80        93          75
# 1        Ribeira Grande  38.52  -28.70     61.79        85         100
# 2             Nantucket  41.28  -70.10     39.20        86          90
# 3              Khatanga  71.97  102.50    -11.20        88          96
# 4                 Avera  33.19  -82.53     43.00       100          75
# 5             Pingliang  35.54  106.69     25.79        68          64
# 6            Georgetown   5.41  100.34     84.20        78          20
# 7                 Vaini -21.20 -175.20     80.60        88          75
# 8  Vila Franca Do Campo  37.72  -25.43     57.20        93          75
# 9          Ponta Do Sol  32.67  -17.10     61.00        82          40
#
#    Wind Speed Country                  Description                 Date
# 0        4.70      CA  light intensity shower rain  2021-01-05 06:15:08
# 1       26.91      PT              overcast clouds  2021-01-05 06:16:37
# 2       16.11      US              overcast clouds  2021-01-05 06:16:38
# 3       18.37      RU              overcast clouds  2021-01-05 06:16:38
# 4        3.36      US                broken clouds  2021-01-05 06:16:38
# 5        3.22      CN                broken clouds  2021-01-05 06:16:38
# 6        5.82      MY                   few clouds  2021-01-05 06:16:39
# 7       11.41      TO                broken clouds  2021-01-05 06:16:39
# 8       18.34      PT                broken clouds  2021-01-05 06:16:39
# 9        5.82      PT                   light rain  2021-01-05 06:16:39

# %%
# Reorder columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description", "Date"]
city_data_df_final = city_data_df[new_column_order]
city_data_df_final.head()
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Port Hardy      CA  50.70 -127.42     42.80        93          75
# 1  Ribeira Grande      PT  38.52  -28.70     61.79        85         100
# 2       Nantucket      US  41.28  -70.10     39.20        86          90
# 3        Khatanga      RU  71.97  102.50    -11.20        88          96
# 4           Avera      US  33.19  -82.53     43.00       100          75
#
#    Wind Speed                  Description                 Date
# 0        4.70  light intensity shower rain  2021-01-05 06:15:08
# 1       26.91              overcast clouds  2021-01-05 06:16:37
# 2       16.11              overcast clouds  2021-01-05 06:16:38
# 3       18.37              overcast clouds  2021-01-05 06:16:38
# 4        3.36                broken clouds  2021-01-05 06:16:38

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df_final.to_csv(output_data_file, index_label="City_ID")
